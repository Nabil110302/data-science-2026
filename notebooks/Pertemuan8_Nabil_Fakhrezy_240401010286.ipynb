# %% [markdown]
# # Pertemuan 8 - Review dan UTS
#
# **Nama:** Nabil Fakhrezy
# **NIM:** 240401010286
# **Kelas:** IF401
# **Program Studi:** PJJ Informatika
#
# ## Materi
# Ringkasan materi dasar Data Science sebelum masuk topik lanjutan.

# %% [markdown]
# ## 1. Ringkasan Materi

# %%
import pandas as pd

ringkasan = pd.DataFrame({
    "Materi": ["Pandas", "Data Cleaning", "Statistika", "Visualisasi", "Preprocessing", "Regresi"],
    "Fungsi": [
        "Mengolah data tabular",
        "Membersihkan missing values dan outlier",
        "Memahami distribusi dan korelasi",
        "Menampilkan pola data",
        "Menyiapkan data untuk model",
        "Memprediksi nilai kontinu"
    ]
})

display(ringkasan)

# %% [markdown]
# ## Kesimpulan
#
# Pertemuan ini menjadi ringkasan materi sebelum topik lanjutan. Temuan utama adalah semua proses Data Science saling berhubungan. Keterbatasannya, bagian ini hanya berupa ringkasan dan bukan praktikum model baru.
